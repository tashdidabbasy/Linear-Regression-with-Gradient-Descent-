# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
data= pd.read_csv("1.01. Simple linear regression.csv")
y=data['SAT'].to_numpy() 
x=data['GPA'].to_numpy()

# %% [markdown]
# # Ploting data

# %%
plt.title("Simple Linear Regression Model")
plt.scatter(x,y)
plt.xlabel("Value of X axis")
plt.ylabel("Value of Y axis")
# Out:
# Text(0, 0.5, 'Value of Y axis')

# %% [markdown]
# # Training the Model

# %%
iteration=20
m=0
c=0
n= len(x)
learning_rate= 0.00212

for i in range(iteration):
    y_pred =m*x+c #Hypothesis 
    d_m = (1/n) * (sum( y_pred -y ) *sum(x)) 
    d_c = (1/n) * (sum(y_pred -y))
    error_squre = (sum((y_pred -y)**2))/ (2*n)
    m= m - learning_rate * d_m
    c= c - learning_rate * d_c
    print("m: {}, c: {}, cost: {}, iteration: {}".format(m,c,error_squre,i))
# Out:
# m: 516.1968954761903, c: 1.8452738095238095, cost: 1707916.005952381, iteration: 0
# m: 550.9881508156889, c: 1.9696437792796488, cost: 13616.93291123804, iteration: 1
# m: 553.3330534268941, c: 1.9780262151529786, cost: 6649.496557466238, iteration: 2
# m: 553.491097975801, c: 1.978591184584976, cost: 6666.99165642216, iteration: 3
# m: 553.5017500512092, c: 1.9786292630700268, cost: 6670.383513500548, iteration: 4
# m: 553.5024679925193, c: 1.978631829529275, cost: 6670.622173469771, iteration: 5
# m: 553.5025163811858, c: 1.978632002506563, cost: 6670.638304620229, iteration: 6
# m: 553.502519642543, c: 1.9786320141650928, cost: 6670.6393920542105, iteration: 7
# m: 553.5025198623559, c: 1.9786320149508685, cost: 6670.639465347333, iteration: 8
# m: 553.5025198771712, c: 1.978632015003829, cost: 6670.639470287236, iteration: 9
# m: 553.5025198781697, c: 1.9786320150073984, cost: 6670.639470620182, iteration: 10
# m: 553.502519878237, c: 1.9786320150076389, cost: 6670.63947064262, iteration: 11
# m: 553.5025198782415, c: 1.9786320150076548, cost: 6670.639470644136, iteration: 12
# m: 553.5025198782417, c: 1.9786320150076557, cost: 6670.63947064424, iteration: 13
# m: 553.5025198782417, c: 1.978632015007656, cost: 6670.639470644242, iteration: 14
# m: 553.5025198782417, c: 1.9786320150076562, cost: 6670.639470644242, iteration: 15
# m: 553.5025198782417, c: 1.9786320150076564, cost: 6670.639470644242, iteration: 16
# m: 553.5025198782417, c: 1.9786320150076566, cost: 6670.639470644242, iteration: 17
# m: 553.5025198782417, c: 1.9786320150076568, cost: 6670.639470644242, iteration: 18
# m: 553.5025198782417, c: 1.978632015007657, cost: 6670.639470644242, iteration: 19

# %% [markdown]
# # Ploting the Regression Line

# %%
predicted_value=m*x+c
plt.plot(x, predicted_value, "k")
plt.scatter(x,y)

# %% [markdown]
# # Prediction

# %%
value = float(input("Enter a value: "))
prediction= m*value+c
print("Prediction is : ", prediction)
# Out:
# Enter a value: 3.59
# Prediction is :  1989.0526783778942
